# %% [markdown]
# # HABITABILITY OF EXOPLANETS USING ML

# %% [markdown]
# ## importing libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv as csv
from sklearn.preprocessing import LabelEncoder
# %matplotlib inline
